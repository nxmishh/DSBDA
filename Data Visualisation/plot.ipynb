# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Cleavland.csv")
df
# Out:
#      63.0  1.0  1.0.1  145.0  233.0  1.0.2  2.0  150.0  0.0  2.3  3.0 0.0.1  \
# 0    67.0  1.0    4.0  160.0  286.0    0.0  2.0  108.0  1.0  1.5  2.0   3.0
# 1    67.0  1.0    4.0  120.0  229.0    0.0  2.0  129.0  1.0  2.6  2.0   2.0
# 2    37.0  1.0    3.0  130.0  250.0    0.0  0.0  187.0  0.0  3.5  3.0   0.0
# 3    41.0  0.0    2.0  130.0  204.0    0.0  2.0  172.0  0.0  1.4  1.0   0.0
# 4    56.0  1.0    2.0  120.0  236.0    0.0  0.0  178.0  0.0  0.8  1.0   0.0
# ..    ...  ...    ...    ...    ...    ...  ...    ...  ...  ...  ...   ...
# 297  45.0  1.0    1.0  110.0  264.0    0.0  0.0  132.0  0.0  1.2  2.0   0.0
# 298  68.0  1.0    4.0  144.0  193.0    1.0  0.0  141.0  0.0  3.4  2.0   2.0
# 299  57.0  1.0    4.0  130.0  131.0    0.0  0.0  115.0  1.0  1.2  2.0   1.0
# 300  57.0  0.0    2.0  130.0  236.0    0.0  2.0  174.0  0.0  0.0  2.0   1.0
# 301  38.0  1.0    3.0  138.0  175.0    0.0  0.0  173.0  0.0  0.0  1.0     ?
#
#      6.0  0
# 0    3.0  2
# 1    7.0  1
# 2    3.0  0
# ...

# %%
plt.figure(figsize=(12,6))
sns.histplot(df["Age"],bins=20,kde=True)
plt.title("Age Histogram")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 plt.figure(figsize=(12,6))
# ...

# %%
plt.figure(figsize=(12,6))
sns.stripplot(x="Sex",y="Age",data=df)
plt.title("Age vs Sex Dot Plot")
plt.xlabel("Sex")
plt.ylabel("Age")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="Sex",y="Age",data=df)
plt.title("Age vs Sex Bar Plot")
plt.xlabel("Sex")
plt.ylabel("Age")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x="Sex",y="Age",data=df)
plt.title("Age vs Sex Line Plot")
plt.xlabel("Sex")
plt.ylabel("Age")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.histplot(df["Age"],bins=20,kde=True)
sns.scatterplot(x="Age",y="Sex",data=df)
sns.boxplot(x="Age",y="Sex",data=df)
plt.title("Age Histogram")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(12,6))
counts=df["Sex"].value_counts()
plt.pie(counts,labels=["Male","Female"],colors=["#f5f521","#f8e1a2"],autopct='%1.1f%%')
plt.title("Sex Ratio")
# plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x="Age",y="Sex",data=df)
sns.boxplot(x="Age",y="Sex",data=df)
plt.title("Boxplot to Scatterplot")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()
